# %% [markdown]
# # AI Resume Screening with NLP and Machine Learning
#
# This Jupyter Notebook extracts text from resumes (PDFs), preprocesses the text, and ranks resumes based on how well they match a given job description using **TF-IDF (Term Frequency - Inverse Document Frequency)** and **cosine similarity**.

# %%
# Import necessary libraries (if not already installed)
# %pip install pandas numpy PyMuPDF nltk scikit-learn

# Import necessary libraries
import os
import fitz # PyMuPDF for PDF extraction
import re
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Download stopwords dataset
nltk.download("stopwords")
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (2.2.6)
# Requirement already satisfied: PyMuPDF in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (1.26.6)
# Requirement already satisfied: nltk in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (3.9.1)
# Requirement already satisfied: scikit-learn in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lahari\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: click in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lahari\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\lahari\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\lahari\appdata\roaming\python\python313\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LAHARI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Step 1: Extract text from PDFs

# We define a function 'extract_text_from_pdf' to extract text from resumes stored as PDFs.


def extract_text_from_pdf(pdf_path):
    """Extracts text from a PDF file using PyMuPDF (fitz)"""
    text = ""
    with fitz.open(pdf_path) as doc:
        for page in doc:
            text += page.get_text("text") + "\n"
    return text

# Define path to your CV
# Use your own path
cv_path = r"C:\Users\LAHARI\Downloads\Lahari_Resume.pdf"

# Extract text from your resume
resume_text = extract_text_from_pdf(cv_path)

# Print the first 2000 characters of extracted text
print(resume_text[:2000])
# Out:
# KUMMARA LAHARI
# Anantapur, IN · +91-6305693869 · lahari11kummara@gmail.com
#
# Summary
# I am an M.Tech graduate in Artificial Intelligence with strong skills in Machine Learning, Data
# Analysis, and Business Insights. Skilled in Python, SQL, and BI tools like Power BI .I have hands-
# on experience in developing ML models, analyzing structured/unstructured data, and presenting
# insights to support decision-making. I enjoy solving problems, learning new technologies, and
# collaborating with teams, and I am eager to contribute in Machine Learning, Data Analytics, or
# Business Analyst roles.
#
# Education
#  - M.Tech in Artificial Intelligence – JNTUA College of Engineering, Anantapur, 2024 | CGPA:
# 9.0
#  - B.Tech in Computer Science & Engineering – Siddharth Institute of Engineering &
# Technology, 2022 | CGPA: 8.44
#  - Intermediate (12th) – Sri Chaithanya Junior College, 2018 | 84%
#  - SSC (10th) – Sri Sai English Medium High School, 2016 | GPA: 9.7
#
# Technical Skills
#  - Programming : Python, SQL
# - Machine Learning: Supervised & Unsupervised Learning, Classification, Regression, Model
# Evaluation
#  - Data Visualization & Reporting: Power BI, Matplotlib, Seaborn
#  - Data Handling: Data Cleaning, Working with Structured & Unstructured data
#  - Soft Skills: Problem-Solving, Critical Thinking, Team Collaboration, Communication
#
# Project
# Loan Approval Prediction with Flask Deployment
# - Built a machine learning solution to predict loan approvals for banking applications.
#
# - Cleaned and prepared the dataset, handled missing values, and scaled features.
# - Conducted exploratory analysis to identify key factors like Credit History, Income, and Property
# Area.
# - Compared multiple models (Logistic Regression, Decision Tree, Random Forest, XGBoost) and
# selected Random Forest, which achieved 85% accuracy.
# - Deployed the model as a Flask web application with an interactive input form.
# - Impact: Enabled faster and more accurate loan approval pre

# %%
## Step 2: Preprocess Text 
"""
We define a function 'preprocess_text' that:
- Converts text to lowercase
- Removes punctuation
- Removes stopwords (common words like "the", "is", "and" that don't add much meaning)
"""

def preprocess_text(text):
    """Cleans and preprocesses text."""
    text = text.lower() # Convert to lowercase
    text = re.sub(r'[^\w\s]','', text) # Remove punctuation
    text = ' '.join([word for word in text.split() if word not in stopwords.words('english')]) # Remove stopwords
    return text

# Example job description
job_description = """
We are looking for a Data Scientist with experience in Python, machine Learning, NLP, and SQL.
"""

# Clean the texts
clean_resume_text = preprocess_text(resume_text)
clean_job_description = preprocess_text(job_description)

# Print cleaned text samples
print(clean_resume_text[:1000])
print(clean_job_description)
# Out:
# kummara lahari anantapur 916305693869 lahari11kummaragmailcom summary mtech graduate artificial intelligence strong skills machine learning data analysis business insights skilled python sql bi tools like power bi hands experience developing ml models analyzing structuredunstructured data presenting insights support decisionmaking enjoy solving problems learning new technologies collaborating teams eager contribute machine learning data analytics business analyst roles education mtech artificial intelligence jntua college engineering anantapur 2024 cgpa 90 btech computer science engineering siddharth institute engineering technology 2022 cgpa 844 intermediate 12th sri chaithanya junior college 2018 84 ssc 10th sri sai english medium high school 2016 gpa 97 technical skills programming python sql machine learning supervised unsupervised learning classification regression model evaluation data visualization reporting power bi matplotlib seaborn data handling data cleaning working structu
# looking data scientist experience python machine learning nlp sql

# %%
## Step 3: Calculate Resume Similarity Score

# We use **TF-IDF** to convert text into numerical vectors and 
# then measure similarity using cosine similarity.


# Convert job description and resumes to TF-IDF vectors
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([clean_job_description, clean_resume_text])

# Compute similarity (closer to 1 = better match)
similarity_score = cosine_similarity(vectors)[0][1]
print(f"Resume Match Score: {similarity_score:.2f}")
# Out:
# Resume Match Score: 0.30

# %%
# Step 4: Process Multiple Resumes in a Folder

# This section processes multiple resumes from a folder and ranks them based on job match score.

# Folder containing resumes
resume_folder = r"C:\\Users\\LAHARI\\OneDrive\\Documents\\Resumes"

# Process multiple resumes
resume_scores = {}
for resume_file in os.listdir(resume_folder):
    resume_text = extract_text_from_pdf(os.path.join(resume_folder, resume_file))
    clean_resume_text = preprocess_text(resume_text)
    
    # Convert to TF-IDF vectors
    vectors = vectorizer.transform([clean_job_description, clean_resume_text])
    similarity_score = cosine_similarity(vectors)[0][1]
    
    resume_scores[resume_file] = similarity_score
# Sort resumes by highest match score
sorted_resumes = sorted(resume_scores.items(), key=lambda x: x[1], reverse=True)

# Print ranked resumes
for resume, score in sorted_resumes:
    print(f"{resume}: {score:.2f}")
# Out:
# Lahari_Resume.pdf: 0.30
# Lahari_Infosys_Resume.pdf: 0.28
# Lahari_SkillInfytech_Resume.pdf: 0.22
# Lahari_Citi_Resume.pdf: 0.22
# Lahari_Pwc_Resume.pdf: 0.22
# Kummara_Lahari_B.Tech.pdf: 0.19
# Kummara_Lahari_Data Analyst.pdf: 0.17
